# %%
# %load_ext tensorboard

# %%
# %%capture
# !pip install datasets
# !pip install tokenizers
# !pip install torchmetrics
# !pip install sacrebleu

# %%
# %%capture
from google.colab import drive
drive.mount('/content/drive')

# %%
# !git clone https://github.com/ankushhKapoor/transformer-from-scratch.git transformer
# %cd /content/drive/transformer

# %%
# %tensorboard --logdir runs

# %%
# !mkdir -p /content/drive/MyDrive/Models/transformer/weights
# !mkdir -p /content/drive/MyDrive/Models/transformer/vocab

# %%
from config import get_config
cfg = get_config()
cfg['model_folder'] = '/content/drive/MyDrive/Models/transformer/weights'
cfg['tokenizer_file'] = '/content/drive/MyDrive/Models/transformer/vocab/tokenizer_{0}.json'
cfg['batch_size'] = 24
cfg['seq_len'] = 350
cfg['num_epochs'] = 30
cfg['preload'] = None
cfg['save_best_only'] = True
cfg['save_every'] = 2

from train import train_model

train_model(cfg)
